# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("FoodBalanceSheets_E_Africa_NOFLAG.csv")

# %%
df.head(10)
# Out:
#    Area Code     Area  Item Code              Item  Element Code  \
# 0          4  Algeria       2501        Population           511
# 1          4  Algeria       2501        Population          5301
# 2          4  Algeria       2901       Grand Total           664
# 3          4  Algeria       2901       Grand Total           674
# 4          4  Algeria       2901       Grand Total           684
# 5          4  Algeria       2903  Vegetal Products           664
# 6          4  Algeria       2903  Vegetal Products           674
# 7          4  Algeria       2903  Vegetal Products           684
# 8          4  Algeria       2941   Animal Products           664
# 9          4  Algeria       2941   Animal Products           674
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60943 entries, 0 to 60942
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Area Code     60943 non-null  int64
#  1   Area          60943 non-null  object
#  2   Item Code     60943 non-null  int64
#  3   Item          60943 non-null  object
#  4   Element Code  60943 non-null  int64
#  5   Element       60943 non-null  object
#  6   Unit          60943 non-null  object
#  7   Y2014         59354 non-null  float64
#  8   Y2015         59395 non-null  float64
#  9   Y2016         59408 non-null  float64
#  10  Y2017         59437 non-null  float64
#  11  Y2018         59507 non-null  float64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 5.6+ MB

# %%
df.describe()

#This gives summary of the data.From this inference,I got the mean and std of Y2015 and to 3 decimal places
# Out:
#           Area Code     Item Code  Element Code          Y2014          Y2015  \
# count  60943.000000  60943.000000  60943.000000   59354.000000   59395.000000
# mean     134.265576   2687.176706   3814.856456     134.196282     135.235966
# std       72.605709    146.055739   2212.007033    1567.663696    1603.403984
# min        4.000000   2501.000000    511.000000   -1796.000000   -3161.000000
# 25%       74.000000   2562.000000    684.000000       0.000000       0.000000
# 50%      136.000000   2630.000000   5142.000000       0.090000       0.080000
# 75%      195.000000   2775.000000   5511.000000       8.340000       8.460000
# max      276.000000   2961.000000   5911.000000  176405.000000  181137.000000
#
#                Y2016          Y2017          Y2018
# count   59408.000000   59437.000000   59507.000000
# mean      136.555222     140.917765     143.758381
# std      1640.007194    1671.862359    1710.782658
# min     -3225.000000   -1582.000000   -3396.000000
# ...

# %%
df.isnull().any()
#checking for null nalues
# Out:
# Area Code       False
# Area            False
# Item Code       False
# Item            False
# Element Code    False
# Element         False
# Unit            False
# Y2014            True
# Y2015            True
# Y2016            True
# Y2017            True
# Y2018            True
# dtype: bool

# %%
df.isnull().sum()


#got sum of missing values (including 2016 from question)
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
df.dropna()
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
df.isna()
# Out:
#        Area Code   Area  Item Code   Item  Element Code  Element   Unit  \
# 0          False  False      False  False         False    False  False
# 1          False  False      False  False         False    False  False
# 2          False  False      False  False         False    False  False
# 3          False  False      False  False         False    False  False
# 4          False  False      False  False         False    False  False
# ...          ...    ...        ...    ...           ...      ...    ...
# 60938      False  False      False  False         False    False  False
# 60939      False  False      False  False         False    False  False
# 60940      False  False      False  False         False    False  False
# 60941      False  False      False  False         False    False  False
# 60942      False  False      False  False         False    False  False
#
#        Y2014  Y2015  Y2016  Y2017  Y2018
# 0      False  False  False  False  False
# ...

# %%
df.shape
# Out:
# (60943, 12)

# %%
t=df.groupby(["Y2014","Y2017"])["Item"].agg(sum)
print(t)
# Out:
# Y2014      Y2017
# -1796.0     0.0             Beverages, Fermented
# -1631.0    -689.0            Alcoholic Beverages
# -849.0     -600.0          Sugar CropsSugar cane
# -838.0     -538.0                  Starchy Roots
# -685.0      689.0       Cereals - Excluding Beer
#                                   ...
#  90425.0    96443.0                   Population
#  98094.0    106400.0                  Population
#  108756.0   112625.0               Starchy Roots
#  109593.0   117702.0               Starchy Roots
#  176405.0   190873.0                  Population
# Name: Item, Length: 14909, dtype: object

# %%
df.groupby(["Y2014"])["Element"].sum()
# Out:
# Y2014
# -1796.0                    Stock Variation
# -1631.0                    Stock Variation
# -849.0                  ResidualsResiduals
# -838.0                     Stock Variation
# -685.0                     Stock Variation
#                          ...
#  90425.0     Total Population - Both sexes
#  98094.0     Total Population - Both sexes
#  108756.0         Domestic supply quantity
#  109593.0                       Production
#  176405.0    Total Population - Both sexes
# Name: Element, Length: 4493, dtype: object

# %%
df.index
# Out:
# RangeIndex(start=0, stop=60943, step=1)

# %%
df.columns
# Out:
# Index(['Area Code', 'Area', 'Item Code', 'Item', 'Element Code', 'Element',
#        'Unit', 'Y2014', 'Y2015', 'Y2016', 'Y2017', 'Y2018'],
#       dtype='object')

# %%
df.groupby(["Element"])["Y2018"].agg([min,max])
# Out:
#                                            min        max
# Element
# Domestic supply quantity                -184.0  117038.00
# Export Quantity                            0.0   34641.00
# Fat supply quantity (g/capita/day)         0.0      94.94
# Feed                                       0.0   31567.00
# Food                                       0.0   54077.00
# Food supply (kcal/capita/day)              0.0    3450.00
# Food supply quantity (kg/capita/yr)        0.0     443.56
# Import Quantity                            0.0   18036.00
# Losses                                     0.0   10355.00
# Other uses (non-food)                      0.0   17221.00
# Processing                                 0.0   22609.00
# Production                                 0.0  118172.00
# Protein supply quantity (g/capita/day)     0.0     101.08
# Residuals                               -598.0   17323.00
# Seed                                       0.0    1474.00
# ...

# %%
df.groupby(["Element"])["Y2014"].sum()
# Out:
# Element
# Domestic supply quantity                  1996716.35
# Export Quantity                            150020.64
# Fat supply quantity (g/capita/day)          10225.56
# Feed                                       216927.89
# Food                                      1212332.49
# Food supply (kcal/capita/day)              454257.00
# Food supply quantity (kg/capita/yr)         49650.63
# Import Quantity                            274144.48
# Losses                                     153223.00
# Other uses (non-food)                       78718.13
# Processing                                 282923.00
# Production                                1931287.75
# Protein supply quantity (g/capita/day)      11836.46
# Residuals                                   30149.00
# Seed                                        21922.92
# Stock Variation                             58749.83
# Total Population - Both sexes             1031585.00
# Tourist consumption                           416.00
# ...

# %%
df.groupby(["Item"])["Y2017"].sum()
# Out:
# Item
# Alcohol, Non-Food        2348.00
# Alcoholic Beverages     95581.06
# Animal Products         11547.65
# Animal fats            269617.53
# Apples and products     10198.90
#                          ...
# Vegetables, Other      157752.59
# Vegetal Products       107655.20
# Wheat and products     240047.62
# Wine                     4178.02
# Yams                   229174.59
# Name: Y2017, Length: 119, dtype: float64

# %%
print(corr_coeff(df))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6016/2504939169.py in <module>
# ----> 1 print(corr_coeff(df))
#
# NameError: name 'corr_coeff' is not defined

# %%
df.groupby("Element")[["Y2014","Y2015","Y2016","Y2017","Y2018"]].sum()
# Out:
#                                              Y2014       Y2015       Y2016  \
# Element
# Domestic supply quantity                1996716.35  2021493.55  2044842.70
# Export Quantity                          150020.64   157614.47   151920.46
# Fat supply quantity (g/capita/day)        10225.56    10235.74    10102.77
# Feed                                     216927.89   225050.22   228958.65
# Food                                    1212332.49  1232361.10  1247022.17
# Food supply (kcal/capita/day)            454257.00   453383.00   451810.00
# Food supply quantity (kg/capita/yr)       49650.63    49345.13    48985.28
# Import Quantity                          274144.48   267018.46   286582.78
# Losses                                   153223.00   155439.00   157787.00
# Other uses (non-food)                     78718.13    66254.41    69563.68
# Processing                               282923.00   287929.00   280631.00
# ...

# %%
df.groupby("Item")[["Y2014","Y2015","Y2016","Y2017","Y2018"]].sum()
# Out:
#                          Y2014      Y2015      Y2016      Y2017      Y2018
# Item
# Alcohol, Non-Food      2403.00    2180.00    2223.00    2348.00    2293.00
# Alcoholic Beverages  102410.11   98783.72   96958.75   95581.06   97847.27
# Animal Products       11935.65   11811.73   11661.69   11547.65   11578.61
# Animal fats          209460.54  200675.72  183314.22  269617.53  269648.27
# Apples and products    9499.23   10559.15    9853.26   10198.90    9640.51
# ...                        ...        ...        ...        ...        ...
# Vegetables, Other    155038.96  158104.08  156218.90  157752.59  163987.21
# Vegetal Products     107145.19  107064.17  106792.72  107655.20  107775.39
# Wheat and products   232670.13  234710.51  239377.07  240047.62  242645.19
# Wine                   4497.36    4251.81    3872.09    4178.02    4039.32
# Yams                 200396.96  203151.78  220626.20  229174.59  221272.09
#
# [119 rows x 5 columns]

# %%
y=df.groupby("Area")[["Y2014","Y2015","Y2016","Y2017","Y2018"]].sum()
print(y)
print(y.shape)
# Out:
#                                   Y2014       Y2015       Y2016       Y2017  \
# Area
# Algeria                       313375.33   324058.40   326007.41   325644.27
# Angola                        208584.42   209565.67   214725.32   229159.57
# Benin                         118050.79   108181.13   117963.59   124771.22
# Botswana                       22339.92    23024.85    22970.65    22101.30
# Burkina Faso                  105051.33   102701.22   107702.27   101855.07
# C?e d'Ivoire                  195982.84   211591.29   211439.20   224599.01
# Cabo Verde                     14576.94    14538.93    14569.40    14650.74
# Cameroon                      217630.28   225220.72   231714.36   232030.43
# Central African Republic       28739.02    28885.34    29454.54    29937.00
# Chad                           65940.17    65835.88    72673.76    71594.68
# Comoros                           32.00       41.34       54.91       59.84
# ...

# %%
t= df["Area"].value_counts()

# %%
print(t)
print(t.size)
# Out:
# Kenya                          1560
# Egypt                          1488
# Nigeria                        1474
# C?e d'Ivoire                   1467
# Senegal                        1462
# Cameroon                       1460
# Uganda                         1458
# Zambia                         1451
# Malawi                         1447
# Ethiopia                       1447
# Madagascar                     1439
# Mozambique                     1427
# Rwanda                         1426
# Angola                         1424
# United Republic of Tanzania    1419
# Congo                          1413
# Guinea                         1410
# Burkina Faso                   1409
# Niger                          1403
# South Africa                   1399
# Zimbabwe                       1393
# Morocco                        1393
# Mauritius                      1378
# Botswana                       1378
# Ghana                          1354
# Central African Republic       1344
# ...

# %%
df.groupby(["Element"])["Y2018"].sum()
# Out:
# Element
# Domestic supply quantity                  2161192.10
# Export Quantity                            181594.80
# Fat supply quantity (g/capita/day)          10258.69
# Feed                                       233489.68
# Food                                      1303841.28
# Food supply (kcal/capita/day)              455261.00
# Food supply quantity (kg/capita/yr)         49056.85
# Import Quantity                            287997.09
# Losses                                     163902.00
# Other uses (non-food)                       91300.97
# Processing                                 308429.00
# Production                                2075072.89
# Protein supply quantity (g/capita/day)      11833.56
# Residuals                                   34864.00
# Seed                                        25263.14
# Stock Variation                             20577.91
# Total Population - Both sexes             1140605.00
# Tourist consumption                            90.00
# ...
